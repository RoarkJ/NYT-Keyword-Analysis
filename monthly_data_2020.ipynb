# %%
import requests
import json
import pandas as pd
import numpy as np
from config import nyt_key
import matplotlib as plt
import sys
import gc
import plotly

import pandas as pd
from pathlib import Path

data_file = r"data/keywords_monthly.csv"

# %%
months = ['3','4','5','6','7']
year = "2020"

#base_url = f"https://api.nytimes.com/svc/archive/v1/{year}/{current_month}.json?api-key={nyt_key}"
#print (base_url)

def cleanup ():
    publication_date = []
    keyword_1 = []
    keyword_2 = []
    keyword_3 = []
    keyword_count_1=0
    keyword_count_2=0
    keyword_count_3=0
    combine=[]
    #del [[df_1]
    gc.enable()
    #print(gc.get_stats())
    return

# %%
#response = requests.get(base_url)
#response

# %%
resp = response.json()

# %%
for month in months:    
    print(month)
    base_url = f"https://api.nytimes.com/svc/archive/v1/{year}/{month}.json?api-key={nyt_key}"
    publication_date = []
    keyword_1 = []
    keyword_2 = []
    keyword_3 = []
    keyword_count_1=0
    keyword_count_2=0
    keyword_count_3=0
    combined=[]
    
        
    response = requests.get(base_url)
    #response
    resp = response.json()

    for i in resp["response"]["docs"]:
        if len(i["keywords"]) >= 3:
            publication_date.append(i["pub_date"])
            keyword_1.append(i["keywords"][0]["value"])
            keyword_2.append(i["keywords"][1]["value"])
            keyword_3.append(i["keywords"][2]["value"])
            keyword_count_1 = df.keyword_1.value_counts()[0:100]
            keyword_count_2 = df.keyword_2.value_counts()[0:100]
            keyword_count_3 = df.keyword_3.value_counts()[0:100]
            combined = pd.concat([keyword_count_1,keyword_count_2,keyword_count_3],axis=1).fillna(0)
            combined = combined["keyword_1"] + combined["keyword_2"] + combined["keyword_3"]
    #data = {
   #     "publication_date":publication_date,
    #    "keyword_1":keyword_1,
    #    "keyword_2":keyword_2,
    #    "keyword_3":keyword_3,
    #        }
  
    #df = pd.DataFrame(data)
                
            
    
    combined.sort_values(ascending=False)[0:50]
    
    data2 = {
        "month":month,
        "combined":combined,
            }
    
    df1 = pd.DataFrame(data2)
    combined_df = pd.DataFrame() 
    combined_df = df.append(df1)
    
     #write each month and keyword to a new column
     #df.to_csv (r'data_file.csv', index = True, header=True)  
    df.to_csv (r'data_file'+month+".csv", index = True, header=True)
    cleanup() #clear memory objects
    
    display(combined_df)
# Out:
# 3
# pandas.core.series.Series
#                                                            publication_date  \
# 0                                                  2020-03-01T07:22:34+0000
# 1                                                  2020-03-01T11:51:43+0000
# 2                                                  2020-03-02T08:00:09+0000
# 3                                                  2020-03-02T08:00:11+0000
# 4                                                  2020-03-01T21:12:51+0000
# ...                                                                     ...
# Asylum, Right of                                                        NaN
# Patient Protection and Affordable Care Act (2010)                       NaN
# AIRPORTS                                                                NaN
# House of Representatives                                                NaN
# Psychology and Psychologists                                            NaN
#
#                                                                        keyword_1  \
# 0                                                                     Television
# 1                                                  Presidential Election of 2020
# 2                                                                       Baseball
# 3                                                            Snow and Snowstorms
# 4                                                        Coronavirus (2019-nCoV)
# ...                                                                          ...
# Asylum, Right of                                                             NaN
# Patient Protection and Affordable Care Act (2010)                            NaN
# AIRPORTS                                                                     NaN
# House of Representatives                                                     NaN
# Psychology and Psychologists                                                 NaN
#
#                                                                           keyword_2  \
# 0                                                  Saturday Night Live (TV Program)
# 1                                                            Primaries and Caucuses
# 2                                                               Los Angeles Dodgers
# 3                                                                     New York City
# 4                                                     Presidential Election of 2020
# ...                                                                             ...
# Asylum, Right of                                                                NaN
# Patient Protection and Affordable Care Act (2010)                               NaN
# AIRPORTS                                                                        NaN
# House of Representatives                                                        NaN
# Psychology and Psychologists                                                    NaN
#
#                                                                keyword_3  \
# 0                                                          Mulaney, John
# 1                                                       Democratic Party
# 2                                                         Houston Astros
# 3                                                         Global Warming
# 4                                                  United States Economy
# ...                                                                  ...
# Asylum, Right of                                                     NaN
# Patient Protection and Affordable Care Act (2010)                    NaN
# AIRPORTS                                                             NaN
# House of Representatives                                             NaN
# Psychology and Psychologists                                         NaN
#
#                                                   month  combined
# 0                                                   NaN       NaN
# 1                                                   NaN       NaN
# 2                                                   NaN       NaN
# 3                                                   NaN       NaN
# 4                                                   NaN       NaN
# ...                                                 ...       ...
# Asylum, Right of                                      3      10.0
# Patient Protection and Affordable Care Act (2010)     3      10.0
# AIRPORTS                                              3      10.0
# House of Representatives                              3      10.0
# Psychology and Psychologists                          3       9.0
#
# [6676 rows x 6 columns]
# 4
# pandas.core.series.Series
#                                  publication_date  \
# 0                        2020-04-01T10:56:16+0000
# 1                        2020-04-02T13:00:21+0000
# 2                        2020-04-02T07:00:08+0000
# 3                        2020-04-01T09:00:26+0000
# 4                        2020-04-02T17:27:56+0000
# ...                                           ...
# AMAZON.COM INC                                NaN
# Disabilities                                  NaN
# Philippines                                   NaN
# Careers and Professions                       NaN
# your-feed-selfcare                            NaN
#
#                                              keyword_1  \
# 0                              Coronavirus (2019-nCoV)
# 1                                Riverdale (Bronx, NY)
# 2                        Pensions and Retirement Plans
# 3                                     Education (K-12)
# 4                              Coronavirus (2019-nCoV)
# ...                                                ...
# AMAZON.COM INC                                     NaN
# Disabilities                                       NaN
# Philippines                                        NaN
# Careers and Professions                            NaN
# your-feed-selfcare                                 NaN
#
#                                                keyword_2  \
# 0                                      Delivery Services
# 1                        Upper West Side (Manhattan, NY)
# 2                                               Taxation
# 3                               Real Estate (Commercial)
# 4                                        Djokovic, Novak
# ...                                                  ...
# AMAZON.COM INC                                       NaN
# Disabilities                                         NaN
# Philippines                                          NaN
# Careers and Professions                              NaN
# your-feed-selfcare                                   NaN
#
#                                           keyword_3 month  combined
# 0                                    AMAZON.COM INC   NaN       NaN
# 1                        Sunset Park (Brooklyn, NY)   NaN       NaN
# 2                                  Local Government   NaN       NaN
# 3                           Nonprofit Organizations   NaN       NaN
# 4                                     Nadal, Rafael   NaN       NaN
# ...                                             ...   ...       ...
# AMAZON.COM INC                                  NaN     4      11.0
# Disabilities                                    NaN     4      10.0
# Philippines                                     NaN     4      10.0
# Careers and Professions                         NaN     4      10.0
# your-feed-selfcare                              NaN     4      10.0
#
# [6706 rows x 6 columns]
# 5
# pandas.core.series.Series
#                                           publication_date  \
# 0                                 2020-05-03T13:10:38+0000
# 1                                 2020-05-01T19:30:09+0000
# 2                                 2020-05-01T05:00:06+0000
# 3                                 2020-05-01T18:24:58+0000
# 4                                 2020-05-02T16:00:07+0000
# ...                                                    ...
# Income Inequality                                      NaN
# Elderly                                                NaN
# Alternative and Renewable Energy                       NaN
# Australia                                              NaN
# Agriculture and Farming                                NaN
#
#                                                 keyword_1  \
# 0                                 Coronavirus (2019-nCoV)
# 1                                              Philosophy
# 2                                                  Tennis
# 3                                       Delivery Services
# 4                                               Birthdays
# ...                                                   ...
# Income Inequality                                     NaN
# Elderly                                               NaN
# Alternative and Renewable Energy                      NaN
# Australia                                             NaN
# Agriculture and Farming                               NaN
#
#                                                keyword_2  \
# 0                                         New York State
# 1                                 Children and Childhood
# 2                                   Universal Tennis LLC
# 3                                            Restaurants
# 4                                       Parties (Social)
# ...                                                  ...
# Income Inequality                                    NaN
# Elderly                                              NaN
# Alternative and Renewable Energy                     NaN
# Australia                                            NaN
# Agriculture and Farming                              NaN
#
#                                                           keyword_3 month  \
# 0                                                     New York City   NaN
# 1                                                         Parenting   NaN
# 2                                                  Sandgren, Tennys   NaN
# 3                                                     United States   NaN
# 4                                 Videophones and Videoconferencing   NaN
# ...                                                             ...   ...
# Income Inequality                                               NaN     5
# Elderly                                                         NaN     5
# Alternative and Renewable Energy                                NaN     5
# Australia                                                       NaN     5
# Agriculture and Farming                                         NaN     5
#
#                                   combined
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# Income Inequality                      9.0
# Elderly                                9.0
# Alternative and Renewable Energy       9.0
# Australia                              9.0
# Agriculture and Farming                9.0
#
# [5697 rows x 6 columns]
# 6
# pandas.core.series.Series
#                                             publication_date  \
# 0                                   2020-06-01T22:02:17+0000
# 1                                   2020-06-02T09:59:40+0000
# 2                                   2020-06-02T15:15:54+0000
# 3                                   2020-06-01T09:00:13+0000
# 4                                   2020-06-03T18:58:35+0000
# ...                                                      ...
# Hydroxychloroquine (Drug)                                NaN
# Banking and Financial Institutions                       NaN
# Agriculture and Farming                                  NaN
# Johnson, Boris                                           NaN
# German Bundesliga                                        NaN
#
#                                                        keyword_1  \
# 0                                   George Floyd Protests (2020)
# 1                                   George Floyd Protests (2020)
# 2                                   George Floyd Protests (2020)
# 3                                      Colleges and Universities
# 4                                   George Floyd Protests (2020)
# ...                                                          ...
# Hydroxychloroquine (Drug)                                    NaN
# Banking and Financial Institutions                           NaN
# Agriculture and Farming                                      NaN
# Johnson, Boris                                               NaN
# German Bundesliga                                            NaN
#
#                                                                     keyword_2  \
# 0                                                                Black People
# 1                                                 Black Lives Matter Movement
# 2                                   United States Defense and Military Forces
# 3                                                     Coronavirus (2019-nCoV)
# 4                                          Demonstrations, Protests and Riots
# ...                                                                       ...
# Hydroxychloroquine (Drug)                                                 NaN
# Banking and Financial Institutions                                        NaN
# Agriculture and Farming                                                   NaN
# Johnson, Boris                                                            NaN
# German Bundesliga                                                         NaN
#
#                                                                 keyword_3  \
# 0                                   Police Department (Minneapolis, Minn)
# 1                                                            Black People
# 2                                                      Defense Department
# 3                                                  Coronavirus Reopenings
# 4                                                Libraries and Librarians
# ...                                                                   ...
# Hydroxychloroquine (Drug)                                             NaN
# Banking and Financial Institutions                                    NaN
# Agriculture and Farming                                               NaN
# Johnson, Boris                                                        NaN
# German Bundesliga                                                     NaN
#
#                                    month  combined
# 0                                    NaN       NaN
# 1                                    NaN       NaN
# 2                                    NaN       NaN
# 3                                    NaN       NaN
# 4                                    NaN       NaN
# ...                                  ...       ...
# Hydroxychloroquine (Drug)              6       9.0
# Banking and Financial Institutions     6       9.0
# Agriculture and Farming                6       9.0
# Johnson, Boris                         6       9.0
# German Bundesliga                      6       9.0
#
# [6274 rows x 6 columns]
# 7
# pandas.core.series.Series
#                                       publication_date  \
# 0                             2020-07-01T23:16:05+0000
# 1                             2020-07-01T14:06:12+0000
# 2                             2020-07-01T21:21:16+0000
# 3                             2020-07-03T02:13:01+0000
# 4                             2020-07-01T15:39:53+0000
# ...                                                ...
# Shortages                                          NaN
# Homeland Security Department                       NaN
# Lewis, John R                                      NaN
# Food                                               NaN
# South Korea                                        NaN
#
#                                                  keyword_1  \
# 0                                                   Russia
# 1                             George Floyd Protests (2020)
# 2                                  Coronavirus (2019-nCoV)
# 3                                               Newspapers
# 4                                      Hollingsworth, Adam
# ...                                                    ...
# Shortages                                              NaN
# Homeland Security Department                           NaN
# Lewis, John R                                          NaN
# Food                                                   NaN
# South Korea                                            NaN
#
#                                                 keyword_2  \
# 0                                                 Taliban
# 1                             Black Lives Matter Movement
# 2                                            Saudi Arabia
# 3                                     News and News Media
# 4                                                  Horses
# ...                                                   ...
# Shortages                                             NaN
# Homeland Security Department                          NaN
# Lewis, John R                                         NaN
# Food                                                  NaN
# South Korea                                           NaN
#
#                                                           keyword_3 month  \
# 0                                                Azizi, Rahmatullah   NaN
# 1                                                    Seattle (Wash)   NaN
# 2                             United States International Relations   NaN
# 3                                        Tribune Publishing Company   NaN
# 4                                                      Black People   NaN
# ...                                                             ...   ...
# Shortages                                                       NaN     7
# Homeland Security Department                                    NaN     7
# Lewis, John R                                                   NaN     7
# Food                                                            NaN     7
# South Korea                                                     NaN     7
#
#                               combined
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# Shortages                          8.0
# Homeland Security Department       8.0
# Lewis, John R                      8.0
# Food                               8.0
# South Korea                        8.0
#
# [5781 rows x 6 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-4de37f7ff41c> in <module>
# ----> 1 pd.concat(['df_march','df_april'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     355                     "only Series and DataFrame objs are valid".format(typ=type(obj))
#     356                 )
# --> 357                 raise TypeError(msg)
#     358
#     359             # consolidate
#
# TypeError: cannot concatenate object of type '<class 'str'>'; only Series and DataFrame objs are valid

# %%
#fig = px.scatter(df, x=publication_date, y=keyword_1,hover_data=[df.index])
#fig.show()
